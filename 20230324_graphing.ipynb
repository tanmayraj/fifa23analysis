# %%
import pandas as pd
import numpy as np

# %%
df_bl = pd.read_csv('./03_results/bothunter_location.csv').iloc[:,1:]
df_ble = pd.read_csv('./03_results/bothunter_location_emotions.csv').iloc[:,1:]
df_blm = pd.read_csv('./03_results/bothunter_location_morals.csv').iloc[:,1:]

# %%
df_bl
# Out:
#              location            region       lat       lon  prediction  \
# 0        `ajlun-20-jo        asia/amman  32.33385  35.75238         0.0
# 1        `ajlun-20-jo        asia/amman  32.33385  35.75238         1.0
# 2        `ajman-02-ae        asia/dubai  25.41111  55.43504         0.0
# 3        `ajman-02-ae        asia/dubai  25.41111  55.43504         1.0
# 4        `ar`ar-15-sa       asia/riyadh  30.97531  41.03808         0.0
# ...               ...               ...       ...       ...         ...
# 5556  zurich-zh112-ch     europe/zurich  47.36667   8.55000         1.0
# 5557    zwickau-13-de     europe/berlin  50.72724  12.48839         0.0
# 5558    zwickau-13-de     europe/berlin  50.72724  12.48839         1.0
# 5559     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         0.0
# 5560     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         1.0
#
#       count  percentage
# 0       161       91.48
# 1        15        8.52
# 2       314       72.52
# ...

# %%
df_bl[df_bl['region']=='prince']
# Out:
#                   location  region       lat       lon  prediction  count  \
# 919      cap haitien-09-au  prince  19.75778 -72.20417         0.0     23
# 920      cap haitien-09-au  prince  19.75778 -72.20417         1.0      7
# 1781        gonaives-06-au  prince  19.45000 -72.68333         0.0     44
# 1782        gonaives-06-au  prince  19.45000 -72.68333         1.0     16
# 2180          jacmel-13-au  prince  18.23417 -72.53472         0.0      1
# 2726       les cayes-12-au  prince  18.20000 -73.75000         0.0     19
# 2727       les cayes-12-au  prince  18.20000 -73.75000         1.0      3
# 3902  port au prince-11-au  prince  18.53917 -72.33500         0.0    795
# 3903  port au prince-11-au  prince  18.53917 -72.33500         1.0     80
#
#       percentage
# 919        76.67
# 920        23.33
# 1781       73.33
# 1782       26.67
# 2180      100.00
# 2726       86.36
# 2727       13.64
# 3902       90.86
# 3903        9.14

# %%
list(set(df_bl['region']))
# Out:
# ['asia/damascus',
#  'europe/london',
#  'australia/darwin',
#  'asia/dili',
#  'america/montevideo',
#  'europe/tirane',
#  'asia/jerusalem',
#  'america/maceio',
#  'atlantic/reykjavik',
#  'asia/irkutsk',
#  'australia/melbourne',
#  'america/la_paz',
#  'africa/accra',
#  'asia/beirut',
#  'asia/vladivostok',
#  'america/caracas',
#  'africa/freetown',
#  'america/recife',
#  'europe/zagreb',
#  'asia/seoul',
#  'prince',
#  'asia/pontianak',
#  'america/santarem',
#  'africa/lagos',
#  'america/curacao',
#  'asia/bishkek',
#  'europe/amsterdam',
#  'america/cuiaba',
#  'america/tijuana',
#  'america/halifax',
#  'africa/brazzaville',
#  'africa/libreville',
#  'africa/harare',
#  'asia/colombo',
#  'europe/oslo',
#  'europe/lisbon',
#  'asia/taipei',
#  'america/boise',
#  'america/santo_domingo',
#  'america/st_johns',
#  'africa/casablanca',
#  'america/fortaleza',
#  'africa/lome',
#  'america/phoenix',
#  'atlantic/madeira',
#  'asia/baghdad',
#  'indian/maldives',
# ...

# %%
region_to_countries = {
    'america/lima' : 'Peru',
    'asia/manila' : 'Philippines',
    'america/chihuahua' : 'Mexico',
    'asia/pyongyang' : 'North Korea',
    'asia/pontianak' : 'Indonesia',
    'australia/sydney' : 'Australia',
    'europe/simferopol' : 'Ukraine',
    'asia/sakhalin' : 'Russia',
    'america/argentina/san_luis' : 'Argentina',
    'asia/dushanbe' : 'Tajikistan',
    'america/santarem' : 'Brazil',
    'america/tegucigalpa' : 'Honduras',
    'america/tijuana' : 'Mexico',
    'asia/irkutsk' : 'Russia',
    'asia/bangkok' : 'Thailand',
    'europe/istanbul' : 'Turkey',
    'america/argentina/la_rioja' : 'Argentina',
    'america/argentina/catamarca' : 'Argentina',
    'africa/kampala' : 'Uganda',
    'asia/beirut' : 'Lebanon',
    'asia/yekaterinburg' : 'Russia',
    'europe/berlin' :  'Germany',
    'america/montreal' : 'Canada',
    'asia/qyzylorda' : 'Kazakhstan',
    'asia/kabul' : 'Afghanistan',
    'asia/baghdad' : 'Iraq',
    'prince' : 'Haiti',
    'america/matamoros' : 'Mexico',
    'asia/makassar' : 'Indonesia',
    'africa/luanda' : 'Angola',
    'europe/ljubljana' : 'Slovenia',
    'america/indiana/indianapolis' : 'United States',
    'america/vancouver' : 'Canada',
    'america/kentucky/louisville' : 'United States',
    'africa/maseru' : 'Lesotho',
    'europe/rome' : 'Italy',
    'america/argentina/salta' : 'Argentina',
    'australia/adelaide' : 'Australia',
    'africa/libreville' : 'Gabon',
    'asia/vientiane' : 'Laos',
    'asia/jakarta' : 'Indonesia',
    'asia/riyadh' : 'Saudi Arabia',
    'asia/macau' : 'China',
    'asia/dubai' : 'United Arab Emirates',
    'america/nassau' : 'Bahamas',
    'america/boa_vista' : 'Cape Verde', 
    'europe/london' : 'United Kingdom',
    'asia/amman' : 'Jordan',
    'europe/uzhgorod' : 'Ukraine', 
    'america/santiago' : 'Chile',
    'europe/skopje' : 'North Macedonia',
    'africa/tripoli' : 'Libya',
    'asia/chongqing' : 'China',
    'asia/ashgabat' : 'Turkmenistan',
    'europe/minsk' : 'Russia',
    'america/regina' : 'Canada',
    'america/asuncion' : 'Paraguay',
    'america/santo_domingo' : 'Dominican Republic',
    'america/belem' : 'Brazil',
    'asia/kuching' : 'Malasia',
    'africa/monrovia' : 'Liberia',
    'europe/zagreb' : 'Croatia',
    'asia/omsk' : 'Russia',
    'asia/hong_kong' : 'China',
    'africa/accra' : 'Ghana',
    'africa/blantyre' : 'Malawi',
    'asia/qatar' : 'Qatar',
    'america/argentina/tucuman' : 'Argentina', 
    'europe/budapest' : 'Hungary',
    'europe/dublin' :  'Ireland',
    'africa/algiers' : 'Algeria', 
    'america/argentina/buenos_aires' : 'Argentina',
    'africa/addis_ababa' : 'Ethiopia',
    'asia/novosibirsk' : 'Russia',
    'europe/warsaw' : 'Poland',
    'america/guayaquil' : 'Ecuador',
    'america/recife' : 'Brazil',
    'australia/brisbane' : 'Australia',
    'asia/seoul' : 'South Korea',
    'asia/kolkata' : 'India',
    'asia/bishkek' : 'Kyrgyzstan',
    'asia/kamchatka' : 'Russia',
    'africa/douala' : 'Cameroon',
    'atlantic/cape_verde' : 'Cape Verde',
    'america/rio_branco' : 'Brazil',
    'asia/tbilisi' : 'Georgia',
    'america/cuiaba' : 'Brazil',
    'america/boise' : 'United States',
    'america/la_paz' : 'Bolivia',
    'africa/kigali' : 'Rwanda',
    'africa/brazzaville' : 'Republic of the Congo',
    'africa/abidjan' : 'Ivory Coast',
    'africa/mogadishu': 'Somalia',
    'europe/lisbon' : 'Portugal',
    'africa/el_aaiun' : 'Western Sahara',
    'africa/bamako' : 'Mali',
    'europe/belgrade' : 'Serbia',
    'australia/melbourne' : 'Australia',
    'asia/bahrain' : 'Bahrain',
    'africa/conakry' : 'Guinea',
    'asia/hebron' : 'Palestine',
    'pacific/honolulu' : 'United States',
    'europe/samara' : 'Russia',
    'indian/mauritius' : 'Mauritius',
    'asia/dhaka' : 'Bangladesh',
    'america/winnipeg' : 'Canada',
    'europe/tallinn' : 'Estonia',
    'asia/dili' : 'East Timor',
    'america/managua' : 'Nicaragua',
    'europe/moscow' : 'Russia',
    'asia/jerusalem' : 'Israel',
    'europe/kaliningrad' : 'Russia',
    'america/porto_velho' : 'Brazil',
    'america/maceio' : 'Brazil',
    'atlantic/reykjavik' : 'Iceland',
    'europe/prague' : 'Czech Republic',
    'asia/urumqi' : 'China',
    'europe/stockholm' : 'Sweden',
    'america/halifax' : 'Canada',
    'asia/shanghai' : 'China',
    'asia/gaza': 'Palestine',
    'europe/podgorica' : 'Montenegro',  
    'asia/karachi' : 'Pakistan',
    'america/guyana' : 'Guyana',
    'africa/cairo' : 'Egypt',
    'africa/lagos' : 'Nigeria',
    'asia/colombo' : 'Sri Lanka',
    'america/edmonton' : 'Canada',
    'europe/kiev' : 'Ukraine',
    'europe/madrid' : 'Spain',
    'asia/kathmandu': 'Nepal',
    'europe/copenhagen' : 'Denmark',
    'america/araguaina' : 'Brazil',
    'africa/djibouti' : 'Djibouti',
    'america/merida' : 'Mexico',
    'europe/paris' : 'France',
    'africa/nairobi' : 'Kenya',
    'america/ojinaga' : 'Mexico',
    'atlantic/madeira' : 'Portugal',
    'africa/niamey' : 'Niger',
    'europe/zaporozhye' : 'Ukraine',
    'asia/rangoon' : 'Myanmar',
    'america/sao_paulo' : 'Brazil',
    'america/monterrey' : 'Mexico',
    'europe/oslo' : 'Norway',
    'america/hermosillo' : 'Mexico',
    'asia/singapore' : 'Singapore',
    'africa/lome' : 'Togo',
    'america/argentina/san_juan' : 'Argentina',
    'africa/dar_es_salaam' : 'Tanzania',
    'asia/aqtau' : 'Kazakhstan',
    'america/phoenix' : 'United States',
    'europe/bucharest' : 'Romania',
    'europe/amsterdam' : 'Netherlands',
    'africa/freetown' : 'Sierra Leone',
    'asia/novokuznetsk' : 'Russia',
    'indian/reunion' : 'France',
    'america/bahia' : 'Brazil',
    'novo' : 'Benin',
    'asia/kuala_lumpur' : 'Malaysia',
    'america/curacao' : 'Curacao',
    'america/panama' : 'Panama',
    'europe/vienna' : 'Austria',
    'africa/casablanca' : 'Morocco',
    'asia/damascus' : 'Syria',
    'america/paramaribo' : 'Suriname',
    'europe/helsinki' : 'Finland',
    'america/moncton' : 'Canada',
    'asia/phnom_penh' : 'Cambodia',
    'america/aruba' : 'Aruba',
    'europe/tirane' : 'Albania',
    'america/manaus' : 'Brazil',
    'america/mexico_city' : 'Mexico',
    'africa/tunis' : 'Tunisia',
    'asia/yerevan' : 'Armenia',
    'america/los_angeles' : 'United States',
    'america/cancun' : 'Mexico',
    'australia/perth' : 'Australia',
    'europe/athens' : 'Greece',
    'america/anchorage' : 'United States',
    'europe/chisinau' : 'Moldova',
    'asia/baku' : 'Azerbaijan',
    'asia/tehran' : 'Iran',
    'america/montevideo' : 'Uruguay',
    'africa/gaborone' : 'Botswana',
    'america/denver' : 'United States',
    'asia/kuwait' : 'Kuwait',
    'asia/jayapura' : 'Indonesia',
    'america/caracas' : 'Venezuela',
    'africa/windhoek' : 'Namibia',
    'indian/antananarivo' : 'Madagascar',
    'europe/vilnius' : 'Lithuania',
    'asia/tokyo' : 'Japan',
    'asia/almaty' : 'Kazakhstan',
    'africa/nouakchott' : 'Mauritania',
    'asia/samarkand' : 'Uzbekistan',
    'america/st_johns' : 'United States',
    'america/argentina/mendoza' : 'Argentina',
    'asia/kashgar' : 'China',
    'asia/nicosia' : 'Cyprus',
    'america/martinique' : 'France',
    'europe/brussels' : 'Belgium',
    'asia/vladivostok' : 'Russia',
    'indian/maldives' : 'Maldives',
    'africa/kinshasa' : 'Democratic Republic of the Congo',
    'europe/zurich' : 'Switzerland', 
    'africa/maputo' : 'Mozambique',
    'asia/tashkent' : 'Uzbekistan',
    'africa/dakar' : 'Senegal',
    'asia/aden' : 'Yemen',
    'america/cayenne' : 'French Guiana',
    'atlantic/canary' : 'Spain',
    'america/jamaica' : 'Jamaica',
    'europe/riga' : 'Latvia',
    'africa/harare' : 'Zimbabwe',
    'america/toronto' : 'Canada',
    'asia/yakutsk' : 'Russia',
    'america/new_york' : 'United States',
    'africa/lusaka' : 'Zambia',
    'africa/mbabane' : 'Swaziland',
    'australia/darwin' : 'Australia',
    'america/port_of_spain' : 'Trinidad and Tobago',
    'america/costa_rica' : 'Costa Rica',
    'europe/volgograd' : 'Russia',
    'america/glace_bay' : 'Canada',
    'america/detroit' : 'United States',
    'asia/muscat' : 'Oman',
    'asia/harbin' : 'China',
    'pacific/port_moresby' : 'Papua New Guinea',
    'africa/lubumbashi' : 'Democratic Republic of the Congo',
    'asia/taipei' : 'Taiwan',
    'pacific/noumea' : 'New Caledonia',
    'america/chicago' : 'United States',
    'america/havana' : 'Cuba',
    'america/argentina/jujuy' : 'Argentina',
    'america/guadeloupe' : 'France',
    'america/argentina/cordoba' : 'Argentina',
    'africa/khartoum' : 'Sudan',
    'africa/johannesburg' : 'South Africa',
    'europe/sofia' : 'Bulgaria',
    'pacific/auckland' : 'New Zealand',
    'europe/sarajevo' : 'Bosnia',
    'europe/bratislava' : 'Slovakia',
    'asia/krasnoyarsk' : 'Russia',
    'asia/aqtobe' : 'Kazakhstan',
    'america/fortaleza' : 'Brazil',
    'america/puerto_rico' : 'Puerto Rico',
    'africa/ouagadougou' : 'Burkina Faso',
    'asia/ulaanbaatar' : 'Mongolia',
    'america/campo_grande' : 'Brazil',
    'africa/bujumbura' : 'Burundi',
    'america/el_salvador' : 'El Salvador',
    'america/bogota' : 'Colombia',
    'america/mazatlan' : 'Mexico',
    'asia/ho_chi_minh' : 'Vietnam',
    'america/guatemala' : 'Guatemala'}

# %%
df_bl['country'] = df_bl['region'].replace(region_to_countries)

# %%
df_bl
# Out:
#              location            region       lat       lon  prediction  \
# 0        `ajlun-20-jo        asia/amman  32.33385  35.75238         0.0
# 1        `ajlun-20-jo        asia/amman  32.33385  35.75238         1.0
# 2        `ajman-02-ae        asia/dubai  25.41111  55.43504         0.0
# 3        `ajman-02-ae        asia/dubai  25.41111  55.43504         1.0
# 4        `ar`ar-15-sa       asia/riyadh  30.97531  41.03808         0.0
# ...               ...               ...       ...       ...         ...
# 5556  zurich-zh112-ch     europe/zurich  47.36667   8.55000         1.0
# 5557    zwickau-13-de     europe/berlin  50.72724  12.48839         0.0
# 5558    zwickau-13-de     europe/berlin  50.72724  12.48839         1.0
# 5559     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         0.0
# 5560     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         1.0
#
#       count  percentage               country
# 0       161       91.48                Jordan
# ...

# %%
df_bl.to_csv('./Analysis/df_bl.csv')

# %%
df_ble['country'] = df_ble['region'].replace(region_to_countries)
df_ble
# Out:
#              location            region       lat       lon  prediction  \
# 0        `ajlun-20-jo        asia/amman  32.33385  35.75238         0.0
# 1        `ajlun-20-jo        asia/amman  32.33385  35.75238         1.0
# 2        `ajman-02-ae        asia/dubai  25.41111  55.43504         0.0
# 3        `ajman-02-ae        asia/dubai  25.41111  55.43504         1.0
# 4        `ar`ar-15-sa       asia/riyadh  30.97531  41.03808         0.0
# ...               ...               ...       ...       ...         ...
# 5470  zurich-zh112-ch     europe/zurich  47.36667   8.55000         1.0
# 5471    zwickau-13-de     europe/berlin  50.72724  12.48839         0.0
# 5472    zwickau-13-de     europe/berlin  50.72724  12.48839         1.0
# 5473     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         0.0
# 5474     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         1.0
#
#          anger   disgust      fear       joy   neutral   sadness  surprise  \
# ...

# %%
df_ble = df_ble.set_index(
    ['location', 'region', 'country', 'lat', 'lon', 'prediction']
).stack().reset_index(name='emotion_value').rename(
    columns={'level_6': 'emotion'})
df_ble
# Out:
#            location            region      country       lat       lon  \
# 0      `ajlun-20-jo        asia/amman       Jordan  32.33385  35.75238
# 1      `ajlun-20-jo        asia/amman       Jordan  32.33385  35.75238
# 2      `ajlun-20-jo        asia/amman       Jordan  32.33385  35.75238
# 3      `ajlun-20-jo        asia/amman       Jordan  32.33385  35.75238
# 4      `ajlun-20-jo        asia/amman       Jordan  32.33385  35.75238
# ...             ...               ...          ...       ...       ...
# 38320  zwolle-15-nl  europe/amsterdam  Netherlands  52.51250   6.09444
# 38321  zwolle-15-nl  europe/amsterdam  Netherlands  52.51250   6.09444
# 38322  zwolle-15-nl  europe/amsterdam  Netherlands  52.51250   6.09444
# 38323  zwolle-15-nl  europe/amsterdam  Netherlands  52.51250   6.09444
# 38324  zwolle-15-nl  europe/amsterdam  Netherlands  52.51250   6.09444
#
#        prediction   emotion  emotion_value
# 0             0.0     anger       0.157472
# ...

# %%
df_ble.to_csv('./Analysis/df_ble.csv')

# %%
df_blm['country'] = df_blm['region'].replace(region_to_countries)
df_blm
# Out:
#              location            region       lat       lon  prediction  \
# 0        `ajlun-20-jo        asia/amman  32.33385  35.75238         0.0
# 1        `ajlun-20-jo        asia/amman  32.33385  35.75238         1.0
# 2        `ajman-02-ae        asia/dubai  25.41111  55.43504         0.0
# 3        `ajman-02-ae        asia/dubai  25.41111  55.43504         1.0
# 4        `ar`ar-15-sa       asia/riyadh  30.97531  41.03808         0.0
# ...               ...               ...       ...       ...         ...
# 5450  zurich-zh112-ch     europe/zurich  47.36667   8.55000         1.0
# 5451    zwickau-13-de     europe/berlin  50.72724  12.48839         0.0
# 5452    zwickau-13-de     europe/berlin  50.72724  12.48839         1.0
# 5453     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         0.0
# 5454     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         1.0
#
#          status_id      code       user_id  probability        Author  ...  \
# ...

# %%
df_blm.columns
# Out:
# Index(['location', 'region', 'lat', 'lon', 'prediction', 'status_id', 'code',
#        'user_id', 'probability', 'Author', 'twitter_id', '# mv_care_virtue',
#        '# mv_care_vice_harm', '# mv_fairness_virtue',
#        '# mv_fairness_vice_cheating', '# mv_loyalty_virtue',
#        '# mv_loyalty_vice_betrayal', '# mv_authority_virtue',
#        '# mv_authority_vice_subversion', '# mv_sanctity_virtue',
#        '# mv_sanctity_vice_degradation', '# mv_liberty_virtue',
#        '# mv_liberty_vice_oppression', 'country'],
#       dtype='object')

# %%
df_blm = df_blm.set_index(
    ['location', 'region', 'country', 'lat', 'lon', 
     'prediction', 'status_id', 'code', 'user_id',
     'Author', 'twitter_id', 'probability']).stack().reset_index(
    name='moral_value').rename(columns={'level_12': 'moral_name'})
df_blm
# Out:
#            location            region      country       lat       lon  \
# 0      `ajlun-20-jo        asia/amman       Jordan  32.33385  35.75238
# 1      `ajlun-20-jo        asia/amman       Jordan  32.33385  35.75238
# 2      `ajlun-20-jo        asia/amman       Jordan  32.33385  35.75238
# 3      `ajlun-20-jo        asia/amman       Jordan  32.33385  35.75238
# 4      `ajlun-20-jo        asia/amman       Jordan  32.33385  35.75238
# ...             ...               ...          ...       ...       ...
# 65455  zwolle-15-nl  europe/amsterdam  Netherlands  52.51250   6.09444
# 65456  zwolle-15-nl  europe/amsterdam  Netherlands  52.51250   6.09444
# 65457  zwolle-15-nl  europe/amsterdam  Netherlands  52.51250   6.09444
# 65458  zwolle-15-nl  europe/amsterdam  Netherlands  52.51250   6.09444
# 65459  zwolle-15-nl  europe/amsterdam  Netherlands  52.51250   6.09444
#
#        prediction     status_id      code       user_id        Author  \
# ...

# %%
df_blm.to_csv('./Analysis/df_blm.csv')
