# %%
import pandas as pd
import numpy as np

import plotly
import plotly.graph_objs as go 
import plotly.offline as offline
import plotly.express as px

# %%
def searchdf(df, **criteria):
    for col, val in criteria.items():
        df=df[df[col]==val]
    return df

# %%
df_bothunter = pd.read_csv('./02_cleaned/bothunter.csv').iloc[:,1:]
df_bothunter
# Out:
#                    status_id              user_id      screen_name  \
# 0        1594177624171237376            149538421  raidou_survivor
# 1        1594178011376455681  1376067487297601537   Nathandrake558
# 2        1594178020062863360   814034558492545024  SanjayS02169973
# 3        1594178104750010370  1558118121587752960   Right130813311
# 4        1594178164456312832  1159168941870256129        Tatastouu
# ...                      ...                  ...              ...
# 1909036  1600875526201217024           3463820669    theressantv91
# 1909037  1600875544073056256  1599400388297474049  LenaHar04634640
# 1909038  1600875577380327425  1401931355554926592  SANTOSH83819519
# 1909039  1600875583814406145   892232820407418880        Wata__Nao
# 1909040  1600875587404693509           1533904146    Mmemberville_
#
#          prediction  probability
# 0               0.0     0.259450
# 1               1.0     0.635951
# 2               1.0     0.788399
# 3               1.0     0.715715
# 4               1.0     0.832714
# ...             ...          ...
# 1909036         1.0     0.778049
# 1909037         1.0     0.552477
# 1909038         1.0     0.842683
# 1909039         0.0     0.229234
# 1909040         1.0     0.843795
#
# [1909041 rows x 5 columns]

# %%
## Reclassify bots with threshold 0.7
## what is the current threshold
print(f"current threshold to classify as bot = {df_bothunter[df_bothunter['prediction']==1]['probability'].min()}")
# Out:
# current threshold to classify as bot = 0.5000001001985493

# %%
df_bothunter.loc[df_bothunter['probability']>=0.7, 'prediction']=1
df_bothunter.loc[df_bothunter['probability']<0.7, 'prediction']=0
print(f"current threshold to classify as bot = {df_bothunter[df_bothunter['prediction']==1]['probability'].min()}")
df_bothunter
# Out:
# current threshold to classify as bot = 0.7000023904177443
#                    status_id              user_id      screen_name  \
# 0        1594177624171237376            149538421  raidou_survivor
# 1        1594178011376455681  1376067487297601537   Nathandrake558
# 2        1594178020062863360   814034558492545024  SanjayS02169973
# 3        1594178104750010370  1558118121587752960   Right130813311
# 4        1594178164456312832  1159168941870256129        Tatastouu
# ...                      ...                  ...              ...
# 1909036  1600875526201217024           3463820669    theressantv91
# 1909037  1600875544073056256  1599400388297474049  LenaHar04634640
# 1909038  1600875577380327425  1401931355554926592  SANTOSH83819519
# 1909039  1600875583814406145   892232820407418880        Wata__Nao
# 1909040  1600875587404693509           1533904146    Mmemberville_
#
#          prediction  probability
# 0               0.0     0.259450
# 1               0.0     0.635951
# 2               1.0     0.788399
# 3               1.0     0.715715
# 4               1.0     0.832714
# ...             ...          ...
# 1909036         1.0     0.778049
# 1909037         0.0     0.552477
# 1909038         1.0     0.842683
# 1909039         0.0     0.229234
# 1909040         1.0     0.843795
#
# [1909041 rows x 5 columns]

# %%
df_location = pd.read_csv('./02_cleaned/location.csv').iloc[:,1:]
df_location
# Out:
#                    status_id        location              region       lat  \
# 0        1604519793281085440     tokyo-40-jp          asia/tokyo  35.68950
# 1        1604519820334366722     tokyo-40-jp          asia/tokyo  35.68950
# 2        1604519820523106304     tokyo-40-jp          asia/tokyo  35.68950
# 3        1604519821130928129     tokyo-40-jp          asia/tokyo  35.68950
# 4        1604519824541245441     tokyo-40-jp          asia/tokyo  35.68950
# ...                      ...             ...                 ...       ...
# 2069003  1594273027298148352   troitsk-13-ru  asia/yekaterinburg  54.09790
# 2069004  1599412673816711169  smolensk-69-ru       europe/moscow  54.78180
# 2069005  1599435234814365699  jhalawar-24-in        asia/kolkata  24.59676
# 2069006  1599445216674516992     biysk-04-ru           asia/omsk  52.53639
# 2069007  1599445595105923073     biysk-04-ru           asia/omsk  52.53639
#
#                lon      code
# 0        139.69171  13126393
# 1        139.69171  13126393
# 2        139.69171  13126393
# 3        139.69171  13126393
# 4        139.69171  13126393
# ...            ...       ...
# 2069003   61.57730    121538
# 2069004   32.04010    320991
# 2069005   76.16503    176133
# 2069006   85.20722    215430
# 2069007   85.20722    215430
#
# [2069008 rows x 6 columns]

# %%
df_emotion = pd.read_csv('./02_cleaned/emotion.csv', low_memory=False).iloc[:,1:]
df_emotion
# Out:
#                       userid       tweetid  \
# 0        1486740205654757379  1.486740e+18
# 1                   18908644  1.890864e+07
# 2        1200599170412875776  1.200599e+18
# 3                 1183565334  1.183565e+09
# 4        1598001705710686208  1.598002e+18
# ...                      ...           ...
# 1470409  1034068444600311812  1.034068e+18
# 1470410   825341312006287361  8.253413e+17
# 1470411             99849659  9.984966e+07
# 1470412  1487871301171744771  1.487871e+18
# 1470413  1557619138117378049  1.557619e+18
#
#                                                       text     anger  \
# 0        #WorldCup2022 Why didn´t Mexico play this way ...  0.027185
# 1        Arjantin atak üstüne atak yapıyor ama aradığı ...  0.112710
# 2        C’est pas Messi qui le rate c’est un arrêt exc...  0.041187
# 3        مشاهدة مباراة السعودية والمكسيك بث مباشر اليوم...  0.180309
# 4        🔴Live Streaming  🏴🇵🇱Poland vs Argentina🇦🇷🏴👉 ht...  0.023232
# ...                                                    ...       ...
# 1470409  RT @q_slavic: #Polska #WorldcupQatar2022. 26.1...  0.066131
# 1470410  RT @SuperExet: Vote for your favourite teams f...  0.100215
# 1470411  Suiza vendiste cara esa clasificación de Brasi...  0.243749
# 1470412  Ganhamos mas lembrando que Tite escalou mal e ...  0.351239
# 1470413  #️⃣ #Brazil #Switzerland #BrazilvsSwitzerland ...  0.054019
#
#           disgust      fear       joy   neutral   sadness  surprise
# 0        0.001112  0.557336  0.005496  0.007620  0.314508  0.086744
# 1        0.031122  0.138428  0.064882  0.439563  0.065871  0.147424
# 2        0.001330  0.940288  0.008016  0.002105  0.004824  0.002250
# 3        0.026082  0.291065  0.032152  0.407928  0.049636  0.012828
# 4        0.002056  0.043861  0.208482  0.464637  0.060417  0.197315
# ...           ...       ...       ...       ...       ...       ...
# 1470409  0.001013  0.907271  0.008250  0.002006  0.012841  0.002488
# 1470410  0.001554  0.560896  0.161231  0.104611  0.014567  0.056926
# 1470411  0.003676  0.658908  0.035601  0.028908  0.010284  0.018874
# 1470412  0.000996  0.486202  0.122127  0.006981  0.025267  0.007188
# 1470413  0.001668  0.825460  0.083121  0.006542  0.019780  0.009410
#
# [1470414 rows x 10 columns]

# %%
## Additional cleaning
df_emotion[df_emotion['userid'].str.isnumeric()==False]
# Out:
#                                                     userid   tweetid  \
# 82800                                       Live Streaming       NaN
# 82801                            👉https://t.co/NynskLIlDgk       NaN
# 82802                               LINK Vidio/SCTV Stream       NaN
# 82803    🔹https://t.co/g7O8GgAuIi… https://t.co/QERdHExc2F  0.068572
# 82825                            👉https://t.co/NynskLqcp8k       NaN
# ...                                                    ...       ...
# 1304670  https://t.co/4hSAs9Kj2e#korea… https://t.co/bn...  0.110659
# 1320620    #WorldCup2022 #WorldCup https://t.co/a744zpF4xc  0.120596
# 1353855              ⚽️ %100 Risksiz Bahis Nakit İade Var!       NaN
# 1353856         ✅ Hemen Kayıt Ol - https://t.co/S4IctpKVLg       NaN
# 1353857                    ⭐️ Nak… https://t.co/Baje8bXbVJ  0.015789
#
#                           text     anger   disgust      fear       joy  \
# 82800                      NaN       NaN       NaN       NaN       NaN
# 82801                      NaN       NaN       NaN       NaN       NaN
# 82802                      NaN       NaN       NaN       NaN       NaN
# 82803     0.007400744594633579  0.203489  0.150625  0.447288  0.048389
# 82825                      NaN       NaN       NaN       NaN       NaN
# ...                        ...       ...       ...       ...       ...
# 1304670  0.0011839079670608044  0.152331  0.508120  0.040178  0.084764
# 1320620  0.0016402131877839565  0.732582  0.075011  0.016603  0.031426
# 1353855                    NaN       NaN       NaN       NaN       NaN
# 1353856                    NaN       NaN       NaN       NaN       NaN
# 1353857  0.0006905265036039054  0.961927  0.007113  0.006494  0.005225
#
#           neutral  sadness  surprise
# 82800         NaN      NaN       NaN
# 82801         NaN      NaN       NaN
# 82802         NaN      NaN       NaN
# 82803    0.074237      NaN       NaN
# 82825         NaN      NaN       NaN
# ...           ...      ...       ...
# 1304670  0.102764      NaN       NaN
# 1320620  0.022142      NaN       NaN
# 1353855       NaN      NaN       NaN
# 1353856       NaN      NaN       NaN
# 1353857  0.002761      NaN       NaN
#
# [974 rows x 10 columns]

# %%
df_emotion = df_emotion[df_emotion['userid'].str.isnumeric()==True]
df_emotion['userid'] = df_emotion['userid'].astype(int)
df_emotion
# Out:
# /var/folders/63/ll_bjqbn4ds7rn24t9dycq6w0000gn/T/ipykernel_38664/4204956019.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       userid       tweetid  \
# 0        1486740205654757379  1.486740e+18
# 1                   18908644  1.890864e+07
# 2        1200599170412875776  1.200599e+18
# 3                 1183565334  1.183565e+09
# 4        1598001705710686208  1.598002e+18
# ...                      ...           ...
# 1470409  1034068444600311812  1.034068e+18
# 1470410   825341312006287361  8.253413e+17
# 1470411             99849659  9.984966e+07
# 1470412  1487871301171744771  1.487871e+18
# 1470413  1557619138117378049  1.557619e+18
#
#                                                       text     anger  \
# 0        #WorldCup2022 Why didn´t Mexico play this way ...  0.027185
# 1        Arjantin atak üstüne atak yapıyor ama aradığı ...  0.112710
# 2        C’est pas Messi qui le rate c’est un arrêt exc...  0.041187
# 3        مشاهدة مباراة السعودية والمكسيك بث مباشر اليوم...  0.180309
# 4        🔴Live Streaming  🏴🇵🇱Poland vs Argentina🇦🇷🏴👉 ht...  0.023232
# ...                                                    ...       ...
# 1470409  RT @q_slavic: #Polska #WorldcupQatar2022. 26.1...  0.066131
# 1470410  RT @SuperExet: Vote for your favourite teams f...  0.100215
# 1470411  Suiza vendiste cara esa clasificación de Brasi...  0.243749
# 1470412  Ganhamos mas lembrando que Tite escalou mal e ...  0.351239
# 1470413  #️⃣ #Brazil #Switzerland #BrazilvsSwitzerland ...  0.054019
#
#           disgust      fear       joy   neutral   sadness  surprise
# 0        0.001112  0.557336  0.005496  0.007620  0.314508  0.086744
# 1        0.031122  0.138428  0.064882  0.439563  0.065871  0.147424
# 2        0.001330  0.940288  0.008016  0.002105  0.004824  0.002250
# 3        0.026082  0.291065  0.032152  0.407928  0.049636  0.012828
# 4        0.002056  0.043861  0.208482  0.464637  0.060417  0.197315
# ...           ...       ...       ...       ...       ...       ...
# 1470409  0.001013  0.907271  0.008250  0.002006  0.012841  0.002488
# 1470410  0.001554  0.560896  0.161231  0.104611  0.014567  0.056926
# 1470411  0.003676  0.658908  0.035601  0.028908  0.010284  0.018874
# 1470412  0.000996  0.486202  0.122127  0.006981  0.025267  0.007188
# 1470413  0.001668  0.825460  0.083121  0.006542  0.019780  0.009410
#
# [1469440 rows x 10 columns]

# %% [markdown]
# ## Bothunter + Location

# %%
df_bothunter_location = df_location.merge(df_bothunter, on='status_id')
df_bothunter_location
# Out:
#                    status_id        location              region       lat  \
# 0        1596845986336641025     tokyo-40-jp          asia/tokyo  35.68950
# 1        1596846000005533696     tokyo-40-jp          asia/tokyo  35.68950
# 2        1596846074031140866     tokyo-40-jp          asia/tokyo  35.68950
# 3        1596846095824396288     tokyo-40-jp          asia/tokyo  35.68950
# 4        1596846208240463872     tokyo-40-jp          asia/tokyo  35.68950
# ...                      ...             ...                 ...       ...
# 1909051  1594273027298148352   troitsk-13-ru  asia/yekaterinburg  54.09790
# 1909052  1599412673816711169  smolensk-69-ru       europe/moscow  54.78180
# 1909053  1599435234814365699  jhalawar-24-in        asia/kolkata  24.59676
# 1909054  1599445216674516992     biysk-04-ru           asia/omsk  52.53639
# 1909055  1599445595105923073     biysk-04-ru           asia/omsk  52.53639
#
#                lon      code              user_id      screen_name  \
# 0        139.69171  13126393  1409063540749520898  xDsjtz0CXfEydkw
# 1        139.69171  13126393  1582581287529099265     bank28829336
# 2        139.69171  13126393  1471383277219250182      NAOKIARAI24
# 3        139.69171  13126393  1468860710574645249    Mason96093167
# 4        139.69171  13126393  1186836309333032960  ZwRvolDalAoCZtO
# ...            ...       ...                  ...              ...
# 1909051   61.57730    121538            420255572           Trozz2
# 1909052   32.04010    320991           2912815271        Stavki_ru
# 1909053   76.16503    176133  1277220460581629958         Mohieb14
# 1909054   85.20722    215430  1406963496546443268  m4opZaqC1GiVeBf
# 1909055   85.20722    215430  1406963496546443268  m4opZaqC1GiVeBf
#
#          prediction  probability
# 0               0.0     0.124301
# 1               1.0     0.807428
# 2               0.0     0.433880
# 3               0.0     0.488711
# 4               1.0     0.769668
# ...             ...          ...
# 1909051         1.0     0.904866
# 1909052         0.0     0.475598
# 1909053         0.0     0.207437
# 1909054         0.0     0.362257
# 1909055         0.0     0.362257
#
# [1909056 rows x 10 columns]

# %%
df_bothunter_freq = pd.DataFrame(df_bothunter_location.groupby(
    ['location', 'region', 'lat', 'lon', 'prediction']).size()).reset_index().rename(columns={0:'count'})
df_bothunter_freq
# Out:
#              location            region       lat       lon  prediction  count
# 0        `ajlun-20-jo        asia/amman  32.33385  35.75238         0.0    161
# 1        `ajlun-20-jo        asia/amman  32.33385  35.75238         1.0     15
# 2        `ajman-02-ae        asia/dubai  25.41111  55.43504         0.0    314
# 3        `ajman-02-ae        asia/dubai  25.41111  55.43504         1.0    119
# 4        `ar`ar-15-sa       asia/riyadh  30.97531  41.03808         0.0     70
# ...               ...               ...       ...       ...         ...    ...
# 5556  zurich-zh112-ch     europe/zurich  47.36667   8.55000         1.0   6308
# 5557    zwickau-13-de     europe/berlin  50.72724  12.48839         0.0    101
# 5558    zwickau-13-de     europe/berlin  50.72724  12.48839         1.0     57
# 5559     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         0.0    505
# 5560     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         1.0    186
#
# [5561 rows x 6 columns]

# %%
df_bothunter_freq.loc[:,'percentage']=(df_bothunter_freq['count']*100/df_bothunter_freq.groupby(['location', 'region', 'lat', 'lon'])['count'].transform('sum')).round(2)
df_bothunter_freq
# Out:
#              location            region       lat       lon  prediction  \
# 0        `ajlun-20-jo        asia/amman  32.33385  35.75238         0.0
# 1        `ajlun-20-jo        asia/amman  32.33385  35.75238         1.0
# 2        `ajman-02-ae        asia/dubai  25.41111  55.43504         0.0
# 3        `ajman-02-ae        asia/dubai  25.41111  55.43504         1.0
# 4        `ar`ar-15-sa       asia/riyadh  30.97531  41.03808         0.0
# ...               ...               ...       ...       ...         ...
# 5556  zurich-zh112-ch     europe/zurich  47.36667   8.55000         1.0
# 5557    zwickau-13-de     europe/berlin  50.72724  12.48839         0.0
# 5558    zwickau-13-de     europe/berlin  50.72724  12.48839         1.0
# 5559     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         0.0
# 5560     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         1.0
#
#       count  percentage
# 0       161       91.48
# 1        15        8.52
# 2       314       72.52
# 3       119       27.48
# 4        70       59.32
# ...     ...         ...
# 5556   6308       62.31
# 5557    101       63.92
# 5558     57       36.08
# 5559    505       73.08
# 5560    186       26.92
#
# [5561 rows x 7 columns]

# %% [markdown]
# ## Bothunter + Location + Emotions

# %%
df_bothunter_location
# Out:
#                    status_id        location              region       lat  \
# 0        1596845986336641025     tokyo-40-jp          asia/tokyo  35.68950
# 1        1596846000005533696     tokyo-40-jp          asia/tokyo  35.68950
# 2        1596846074031140866     tokyo-40-jp          asia/tokyo  35.68950
# 3        1596846095824396288     tokyo-40-jp          asia/tokyo  35.68950
# 4        1596846208240463872     tokyo-40-jp          asia/tokyo  35.68950
# ...                      ...             ...                 ...       ...
# 1909051  1594273027298148352   troitsk-13-ru  asia/yekaterinburg  54.09790
# 1909052  1599412673816711169  smolensk-69-ru       europe/moscow  54.78180
# 1909053  1599435234814365699  jhalawar-24-in        asia/kolkata  24.59676
# 1909054  1599445216674516992     biysk-04-ru           asia/omsk  52.53639
# 1909055  1599445595105923073     biysk-04-ru           asia/omsk  52.53639
#
#                lon      code              user_id      screen_name  \
# 0        139.69171  13126393  1409063540749520898  xDsjtz0CXfEydkw
# 1        139.69171  13126393  1582581287529099265     bank28829336
# 2        139.69171  13126393  1471383277219250182      NAOKIARAI24
# 3        139.69171  13126393  1468860710574645249    Mason96093167
# 4        139.69171  13126393  1186836309333032960  ZwRvolDalAoCZtO
# ...            ...       ...                  ...              ...
# 1909051   61.57730    121538            420255572           Trozz2
# 1909052   32.04010    320991           2912815271        Stavki_ru
# 1909053   76.16503    176133  1277220460581629958         Mohieb14
# 1909054   85.20722    215430  1406963496546443268  m4opZaqC1GiVeBf
# 1909055   85.20722    215430  1406963496546443268  m4opZaqC1GiVeBf
#
#          prediction  probability
# 0               0.0     0.124301
# 1               1.0     0.807428
# 2               0.0     0.433880
# 3               0.0     0.488711
# 4               1.0     0.769668
# ...             ...          ...
# 1909051         1.0     0.904866
# 1909052         0.0     0.475598
# 1909053         0.0     0.207437
# 1909054         0.0     0.362257
# 1909055         0.0     0.362257
#
# [1909056 rows x 10 columns]

# %%
df_emotion
# Out:
#                       userid       tweetid  \
# 0        1486740205654757379  1.486740e+18
# 1                   18908644  1.890864e+07
# 2        1200599170412875776  1.200599e+18
# 3                 1183565334  1.183565e+09
# 4        1598001705710686208  1.598002e+18
# ...                      ...           ...
# 1470409  1034068444600311812  1.034068e+18
# 1470410   825341312006287361  8.253413e+17
# 1470411             99849659  9.984966e+07
# 1470412  1487871301171744771  1.487871e+18
# 1470413  1557619138117378049  1.557619e+18
#
#                                                       text     anger  \
# 0        #WorldCup2022 Why didn´t Mexico play this way ...  0.027185
# 1        Arjantin atak üstüne atak yapıyor ama aradığı ...  0.112710
# 2        C’est pas Messi qui le rate c’est un arrêt exc...  0.041187
# 3        مشاهدة مباراة السعودية والمكسيك بث مباشر اليوم...  0.180309
# 4        🔴Live Streaming  🏴🇵🇱Poland vs Argentina🇦🇷🏴👉 ht...  0.023232
# ...                                                    ...       ...
# 1470409  RT @q_slavic: #Polska #WorldcupQatar2022. 26.1...  0.066131
# 1470410  RT @SuperExet: Vote for your favourite teams f...  0.100215
# 1470411  Suiza vendiste cara esa clasificación de Brasi...  0.243749
# 1470412  Ganhamos mas lembrando que Tite escalou mal e ...  0.351239
# 1470413  #️⃣ #Brazil #Switzerland #BrazilvsSwitzerland ...  0.054019
#
#           disgust      fear       joy   neutral   sadness  surprise
# 0        0.001112  0.557336  0.005496  0.007620  0.314508  0.086744
# 1        0.031122  0.138428  0.064882  0.439563  0.065871  0.147424
# 2        0.001330  0.940288  0.008016  0.002105  0.004824  0.002250
# 3        0.026082  0.291065  0.032152  0.407928  0.049636  0.012828
# 4        0.002056  0.043861  0.208482  0.464637  0.060417  0.197315
# ...           ...       ...       ...       ...       ...       ...
# 1470409  0.001013  0.907271  0.008250  0.002006  0.012841  0.002488
# 1470410  0.001554  0.560896  0.161231  0.104611  0.014567  0.056926
# 1470411  0.003676  0.658908  0.035601  0.028908  0.010284  0.018874
# 1470412  0.000996  0.486202  0.122127  0.006981  0.025267  0.007188
# 1470413  0.001668  0.825460  0.083121  0.006542  0.019780  0.009410
#
# [1469440 rows x 10 columns]

# %% [markdown]
# #### Approach: Check each emotion message is bot or not and what location was it

# %%
searchdf(df_bothunter_location, user_id=1486740205654757379)
# Out:
#                   status_id           location               region       lat  \
# 852313  1598040909949636635  mexico city-09-mx  america/mexico_city  19.42847
# 853715  1598063782559092737  mexico city-09-mx  america/mexico_city  19.42847
# 864851  1598039182584459265  mexico city-09-mx  america/mexico_city  19.42847
#
#              lon      code              user_id  screen_name  prediction  \
# 852313 -99.12766  21375109  1486740205654757379  CQuillwitch         0.0
# 853715 -99.12766  21375109  1486740205654757379  CQuillwitch         0.0
# 864851 -99.12766  21375109  1486740205654757379  CQuillwitch         0.0
#
#         probability
# 852313     0.287861
# 853715     0.287861
# 864851     0.282930

# %%
df_emotion['userid'].map(df_bothunter_location['user_id'].value_counts())
# Out:
# 0             3
# 1            57
# 2             8
# 3           461
# 4           739
#            ...
# 1470409       9
# 1470410       1
# 1470411       3
# 1470412       3
# 1470413    1072
# Name: userid, Length: 1469440, dtype: int64

# %% [markdown]
# #### Approach: Check each bothunter and find message

# %%
searchdf(df_emotion, userid=1409063540749520898)
# Out:
#                      userid       tweetid  \
# 136405  1409063540749520898  1.409064e+18
#
#                                                      text     anger  disgust  \
# 136405  RT @avshimiken: 日本負けてザワついてるけど負けた方が学びは大きい。436万人...  0.114485  0.00767
#
#             fear       joy   neutral   sadness  surprise
# 136405  0.058999  0.036845  0.650033  0.024435  0.107532

# %%
df_bothunter_location['user_id'].map(df_emotion['userid'].value_counts())
# Out:
# 0           1.0
# 1           2.0
# 2           5.0
# 3           1.0
# 4           1.0
#            ...
# 1909051     1.0
# 1909052    25.0
# 1909053     2.0
# 1909054     2.0
# 1909055     2.0
# Name: user_id, Length: 1909056, dtype: float64

# %%
df_bothunter_location.loc[2, 'user_id']
# Out:
# 1471383277219250182

# %%
searchdf(df_emotion, userid=1471383277219250182)
# Out:
#                       userid       tweetid  \
# 136451   1471383277219250182  1.471383e+18
# 567717   1471383277219250182  1.471383e+18
# 862196   1471383277219250182  1.471383e+18
# 1165056  1471383277219250182  1.471383e+18
# 1403617  1471383277219250182  1.471383e+18
#
#                                                       text     anger  \
# 136451   森保監督、旗手レオって選手知ってますか？#日本代表 #川崎フロンターレ #WorldcupQ...  0.363263
# 567717   20.21年、川崎フロンターレが無双してた時にめちゃくちゃこの形が多かったのよね。だから絶対...  0.411750
# 862196   RT @NAOKIARAI24: 20.21年、川崎フロンターレが無双してた時にめちゃくちゃ...  0.236091
# 1165056  俺たちのキャプテン谷口彰悟を「川崎でしょ？所詮JだからW杯じゃ使えない」って言ってた勢、息し...  0.340980
# 1403617  サッカー日本代表はいつのまに3バック(5バック)がデェフォルトになった？クロアチア4-3-3...  0.168840
#
#           disgust      fear       joy   neutral   sadness  surprise
# 136451   0.001493  0.552643  0.046814  0.009443  0.016785  0.009559
# 567717   0.009597  0.263775  0.044865  0.179136  0.033793  0.057083
# 862196   0.004718  0.173566  0.046519  0.377230  0.043807  0.118069
# 1165056  0.001449  0.538988  0.070629  0.014242  0.019808  0.013903
# 1403617  0.035162  0.046104  0.053964  0.542427  0.034925  0.118578

# %% [markdown]
# #### Approach : Lets take aggregate emotions of each userid

# %%
df_emotion_mean = df_emotion.groupby('userid').mean().reset_index()
df_emotion_mean
# Out:
# /var/folders/63/ll_bjqbn4ds7rn24t9dycq6w0000gn/T/ipykernel_38664/1660352911.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#                      userid       tweetid     anger   disgust      fear  \
# 0                      1984  1.984000e+03  0.006145  0.000630  0.015928
# 1                      2360  2.360000e+03  0.042762  0.004938  0.005220
# 2                      2638  2.638000e+03  0.052312  0.000532  0.184528
# 3                      2654  2.654000e+03  0.024027  0.000333  0.964293
# 4                      2764  2.764000e+03  0.093482  0.000509  0.748499
# ...                     ...           ...       ...       ...       ...
# 682571  1600870000306290694  1.600870e+18  0.057905  0.001571  0.471044
# 682572  1600870006556078080  1.600870e+18  0.066724  0.003232  0.006440
# 682573  1600870378334822401  1.600870e+18  0.018179  0.001184  0.083089
# 682574  1600870668521902082  1.600871e+18  0.018179  0.001184  0.083089
# 682575  1600871030825705472  1.600871e+18  0.072692  0.003520  0.005837
#
#              joy   neutral   sadness  surprise
# 0       0.654465  0.144237  0.068406  0.110188
# 1       0.367041  0.379256  0.012330  0.188454
# 2       0.676653  0.028803  0.017081  0.040091
# 3       0.001881  0.001760  0.006262  0.001444
# 4       0.094303  0.008575  0.028541  0.026090
# ...          ...       ...       ...       ...
# 682571  0.452961  0.002181  0.010526  0.003814
# 682572  0.054055  0.801003  0.011178  0.057368
# 682573  0.027319  0.469531  0.037896  0.362803
# 682574  0.027319  0.469531  0.037896  0.362803
# 682575  0.049664  0.802488  0.010700  0.055099
#
# [682576 rows x 9 columns]

# %%
searchdf(df_emotion, userid=1984)
# Out:
#        userid  tweetid                                               text  \
# 95764    1984   1984.0  Nice to see a Croatia fan wearing a water polo...
# 96339    1984   1984.0  #WorldcupQatar2022 Nice to see a Croatia fan w...
# 96781    1984   1984.0                    #WorldcupQatar2022 Oh. Canada 😔
#
#           anger   disgust      fear       joy   neutral   sadness  surprise
# 95764  0.002284  0.000640  0.002769  0.978869  0.002824  0.001508  0.011107
# 96339  0.003617  0.000375  0.011664  0.952882  0.002489  0.002476  0.026497
# 96781  0.012536  0.000876  0.033352  0.031644  0.427400  0.201233  0.292961

# %% [markdown]
# #### Merge

# %%
df_bothunter_location['user_id'].map(df_emotion_mean['userid'].value_counts())
# Out:
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
#           ...
# 1909051    1.0
# 1909052    1.0
# 1909053    1.0
# 1909054    1.0
# 1909055    1.0
# Name: user_id, Length: 1909056, dtype: float64

# %%
df_bothunter_location_emotion = df_bothunter_location.merge(df_emotion_mean, left_on='user_id', right_on='userid')
df_bothunter_location_emotion
# Out:
#                    status_id                  location               region  \
# 0        1596845986336641025               tokyo-40-jp           asia/tokyo
# 1        1596846000005533696               tokyo-40-jp           asia/tokyo
# 2        1596846100245204993  city of london-enggla-gb        europe/london
# 3        1596846074031140866               tokyo-40-jp           asia/tokyo
# 4        1599777190031552512               tokyo-40-jp           asia/tokyo
# ...                      ...                       ...                  ...
# 1670577  1599493185579122689               praia-14-cv  atlantic/cape_verde
# 1670578  1597638985299677184           cherkessk-27-ru        europe/moscow
# 1670579  1597651605402550273       nizhniy tagil-71-ru   asia/yekaterinburg
# 1670580  1599445216674516992               biysk-04-ru            asia/omsk
# 1670581  1599445595105923073               biysk-04-ru            asia/omsk
#
#               lat        lon      code              user_id      screen_name  \
# 0        35.68950  139.69171  13126393  1409063540749520898  xDsjtz0CXfEydkw
# 1        35.68950  139.69171  13126393  1582581287529099265     bank28829336
# 2        51.51279   -0.09184  17401356  1582581287529099265     bank28829336
# 3        35.68950  139.69171  13126393  1471383277219250182      NAOKIARAI24
# 4        35.68950  139.69171  13126393  1471383277219250182      NAOKIARAI24
# ...           ...        ...       ...                  ...              ...
# 1670577  14.93152  -23.51254    113364            290417672            DecB1
# 1670578  44.22333   42.05778    165343  1199625404211970055    semoo78361093
# 1670579  57.91944   59.96500    534796  1279128886794690571     Solomonovna_
# 1670580  52.53639   85.20722    215430  1406963496546443268  m4opZaqC1GiVeBf
# 1670581  52.53639   85.20722    215430  1406963496546443268  m4opZaqC1GiVeBf
#
#          prediction  probability               userid       tweetid     anger  \
# 0               0.0     0.124301  1409063540749520898  1.409064e+18  0.114485
# 1               1.0     0.807428  1582581287529099265  1.582581e+18  0.235524
# 2               1.0     0.807428  1582581287529099265  1.582581e+18  0.235524
# 3               0.0     0.433880  1471383277219250182  1.471383e+18  0.304185
# 4               0.0     0.423582  1471383277219250182  1.471383e+18  0.304185
# ...             ...          ...                  ...           ...       ...
# 1670577         0.0     0.207060            290417672  2.904177e+08  0.017681
# 1670578         0.0     0.471277  1199625404211970055  1.199625e+18  0.059752
# 1670579         0.0     0.323670  1279128886794690571  1.279129e+18  0.048558
# 1670580         0.0     0.362257  1406963496546443268  1.406963e+18  0.039512
# 1670581         0.0     0.362257  1406963496546443268  1.406963e+18  0.039512
#
#           disgust      fear       joy   neutral   sadness  surprise
# 0        0.007670  0.058999  0.036845  0.650033  0.024435  0.107532
# 1        0.017881  0.192412  0.042720  0.369554  0.093387  0.048522
# 2        0.017881  0.192412  0.042720  0.369554  0.093387  0.048522
# 3        0.010484  0.315015  0.052558  0.224495  0.029824  0.063438
# 4        0.010484  0.315015  0.052558  0.224495  0.029824  0.063438
# ...           ...       ...       ...       ...       ...       ...
# 1670577  0.006556  0.014743  0.022087  0.626479  0.085669  0.226785
# 1670578  0.000727  0.918987  0.006249  0.004456  0.007769  0.002060
# 1670579  0.003467  0.834547  0.035404  0.031498  0.029394  0.017133
# 1670580  0.001147  0.428256  0.288044  0.120015  0.018865  0.104160
# 1670581  0.001147  0.428256  0.288044  0.120015  0.018865  0.104160
#
# [1670582 rows x 19 columns]

# %%
# df_ble_freq = 
pd.DataFrame(df_bothunter_location_emotion.groupby(
    ['location', 'region', 'lat', 'lon', 'prediction']).agg({'anger':'mean', 
                                                             'disgust':'mean',
                                                             'fear':'mean',
                                                             'joy':'mean',
                                                             'neutral':'mean',
                                                             'sadness':'mean',
                                                             'surprise':'mean'}).reset_index())
# Out:
#              location            region       lat       lon  prediction  \
# 0        `ajlun-20-jo        asia/amman  32.33385  35.75238         0.0
# 1        `ajlun-20-jo        asia/amman  32.33385  35.75238         1.0
# 2        `ajman-02-ae        asia/dubai  25.41111  55.43504         0.0
# 3        `ajman-02-ae        asia/dubai  25.41111  55.43504         1.0
# 4        `ar`ar-15-sa       asia/riyadh  30.97531  41.03808         0.0
# ...               ...               ...       ...       ...         ...
# 5470  zurich-zh112-ch     europe/zurich  47.36667   8.55000         1.0
# 5471    zwickau-13-de     europe/berlin  50.72724  12.48839         0.0
# 5472    zwickau-13-de     europe/berlin  50.72724  12.48839         1.0
# 5473     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         0.0
# 5474     zwolle-15-nl  europe/amsterdam  52.51250   6.09444         1.0
#
#          anger   disgust      fear       joy   neutral   sadness  surprise
# 0     0.157472  0.013708  0.562638  0.108387  0.108624  0.032528  0.016644
# 1     0.138439  0.016309  0.525496  0.058550  0.207979  0.034809  0.018420
# 2     0.115801  0.004742  0.672756  0.064339  0.088702  0.031953  0.021706
# 3     0.137027  0.008245  0.593775  0.066983  0.143962  0.029433  0.020576
# 4     0.126709  0.019092  0.711986  0.027177  0.083284  0.023746  0.008006
# ...        ...       ...       ...       ...       ...       ...       ...
# 5470  0.050774  0.002235  0.255058  0.129349  0.437428  0.033761  0.091395
# 5471  0.118323  0.008310  0.553897  0.086094  0.125446  0.071881  0.036049
# 5472  0.105689  0.009183  0.582490  0.068055  0.136838  0.063264  0.034481
# 5473  0.115759  0.003075  0.438510  0.093060  0.215188  0.054410  0.079999
# 5474  0.128108  0.002996  0.452828  0.076322  0.227367  0.042848  0.069530
#
# [5475 rows x 12 columns]
